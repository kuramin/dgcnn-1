# %%
import argparse
import math
import h5py
import numpy as np
import tensorflow as tf
import socket
import importlib
import os
import sys
# Out:
# /home/kuramin/miniconda3/envs/env_gpu_tf1.11/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/kuramin/miniconda3/envs/env_gpu_tf1.11/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/kuramin/miniconda3/envs/env_gpu_tf1.11/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/kuramin/miniconda3/envs/env_gpu_tf1.11/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/kuramin/miniconda3/envs/env_gpu_tf1.11/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/kuramin/miniconda3/envs/env_gpu_tf1.11/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
BASE_DIR = os.getcwd()
sys.path.append(BASE_DIR)
sys.path.append(os.path.join(BASE_DIR, 'models'))
sys.path.append(os.path.join(BASE_DIR, 'utils'))
print(BASE_DIR)
# Out:
# /home/kuramin/Diploma/repos/DGCNN_tf/dgcnn-1/tensorflow

# %%
import provider
from utils import tf_util

# %%
BATCH_SIZE = 24
NUM_POINT = 1024
MAX_EPOCH = 50 #250
BASE_LEARNING_RATE = 0.001
GPU_INDEX = 0
MOMENTUM = 0.9
OPTIMIZER = 'adam'
DECAY_STEP = 200000
DECAY_RATE = 0.7

# %%
MODEL = importlib.import_module('dgcnn')  # import network module
MODEL_FILE = os.path.join(BASE_DIR, 'models', 'dgcnn.py')
LOG_DIR = 'log'
if not os.path.exists(LOG_DIR):
    os.mkdir(LOG_DIR)
# os.system('cp %s %s' % (MODEL_FILE, LOG_DIR)) # bkp of model def
# os.system('cp train.py %s' % (LOG_DIR)) # bkp of train procedure
LOG_FOUT = open(os.path.join(LOG_DIR, 'log_train.txt'), 'w')
LOG_FOUT.write("BATCH_SIZE = 24, NUM_POINT = 1024, MAX_EPOCH = 250, BASE_LEARNING_RATE = 0.001, GPU_INDEX = 0, MOMENTUM = 0.9, OPTIMIZER = 'adam', DECAY_STEP = 200000, DECAY_RATE = 0.7\n")

MAX_NUM_POINT = 4096 #2048
NUM_CLASSES = 40

BN_INIT_DECAY = 0.5
BN_DECAY_DECAY_RATE = 0.5
BN_DECAY_DECAY_STEP = float(DECAY_STEP)
BN_DECAY_CLIP = 0.99

HOSTNAME = socket.gethostname()

# %%
# ModelNet40 official train/test split
TRAIN_FILES = provider.get_data_files( \
    os.path.join(BASE_DIR, 'data/modelnet40_ply_hdf5_2048/train_files.txt'))
TEST_FILES = provider.get_data_files( \
    os.path.join(BASE_DIR, 'data/modelnet40_ply_hdf5_2048/test_files.txt'))

# %%
def log_string(log_file, out_str):
    log_file.write(out_str + '\n')
    log_file.flush()
    print(out_str)


def get_learning_rate(batch):
    learning_rate = tf.train.exponential_decay(
        BASE_LEARNING_RATE,  # Base learning rate.
        batch * BATCH_SIZE,  # Current index into the dataset.
        DECAY_STEP,  # Decay step.
        DECAY_RATE,  # Decay rate.
        staircase=True)
    learning_rate = tf.maximum(learning_rate, 0.00001)  # don't allow learning rate go beyond 0.00001
    return learning_rate


def get_bn_decay(batch):
    bn_momentum = tf.train.exponential_decay(
        BN_INIT_DECAY,
        batch * BATCH_SIZE,
        BN_DECAY_DECAY_STEP,
        BN_DECAY_DECAY_RATE,
        staircase=True)
    bn_decay = tf.minimum(BN_DECAY_CLIP, 1 - bn_momentum)
    return bn_decay


def train():
    with tf.Graph().as_default():
        with tf.device('/gpu:' + str(GPU_INDEX)):
            pointclouds_pl, labels_pl = MODEL.placeholder_inputs(BATCH_SIZE,
                                                                 NUM_POINT)  # create placeholders using method
            is_training_pl = tf.placeholder(tf.bool, shape=())
            print(is_training_pl)

            # Note the global_step=batch parameter to minimize. 
            # That tells the optimizer to helpfully increment the 'batch' parameter for you every time it trains.
            batch = tf.Variable(0)
            bn_decay = get_bn_decay(batch)
            tf.summary.scalar('bn_decay', bn_decay)

            # Get prediction and loss based on placeholders
            pred, end_points = MODEL.get_model(pointclouds_pl, is_training_pl,
                                               bn_decay=bn_decay)  # predictions on probabilities of BATCH_SIZE clouds belonging to 40 classes
            loss = MODEL.get_loss(pred, labels_pl,
                                  end_points)  # value of loss for batch, based on difference of predictions and true values of classes for BATCH_SIZE clouds
            tf.summary.scalar('loss', loss)

            correct = tf.equal(tf.argmax(pred, 1), tf.to_int64(
                labels_pl))  # vector of booleans of correct guesses, based on predictions and and true values of classes for BATCH_SIZE clouds
            accuracy = tf.reduce_sum(tf.cast(correct, tf.float32)) / float(
                BATCH_SIZE)  # cast vector of corrects to float, define number of corrects and divide by total number
            tf.summary.scalar('accuracy', accuracy)

            # Get training operator
            learning_rate = get_learning_rate(batch)  # calculate current value of learning rate
            tf.summary.scalar('learning_rate', learning_rate)
            if OPTIMIZER == 'momentum':
                optimizer = tf.train.MomentumOptimizer(learning_rate, momentum=MOMENTUM)
            elif OPTIMIZER == 'adam':
                optimizer = tf.train.AdamOptimizer(learning_rate)
            train_op = optimizer.minimize(loss, global_step=batch)  # define what does optimizer minimize

            # Add ops to save and restore all the variables.
            saver = tf.train.Saver()

        # Create a session
        config = tf.ConfigProto()
        config.gpu_options.allow_growth = True
        config.allow_soft_placement = True
        config.log_device_placement = False
        sess = tf.Session(config=config)

        # Add summary writers
        # merged = tf.merge_all_summaries()
        merged = tf.summary.merge_all()
        train_writer = tf.summary.FileWriter(os.path.join(LOG_DIR, 'train'),
                                             sess.graph)
        test_writer = tf.summary.FileWriter(os.path.join(LOG_DIR, 'test'))

        # Init variables
        init = tf.global_variables_initializer()
        # To fix the bug introduced in TF 0.12.1 as in
        # http://stackoverflow.com/questions/41543774/invalidargumenterror-for-tensor-bool-tensorflow-0-12-1
        # sess.run(init)
        sess.run(init, {is_training_pl: True})

        ops = {'pointclouds_pl': pointclouds_pl,
               'labels_pl': labels_pl,
               'is_training_pl': is_training_pl,
               'pred': pred,
               'loss': loss,
               'train_op': train_op,
               'merged': merged,
               'step': batch}

        # for every epoch in range 0 to MAX_EPOCH - 1 do train, evaluation and saving
        for epoch in range(MAX_EPOCH):
            log_string(LOG_FOUT, '**** EPOCH %03d ****' % (epoch))
            sys.stdout.flush()

            # training within every epoch will be done using 5 train-files,
            # dividing each into pieces of size BATCH_SIZE
            # BATCH_SIZE of clouds with different labels
            train_one_epoch(sess, ops, train_writer)

            # evaluation within every epoch
            eval_one_epoch(sess, ops, test_writer)

            # Save the variables to disk.
            if epoch % 10 == 0:
                save_path = saver.save(sess, os.path.join(LOG_DIR, "model.ckpt"))
                log_string(LOG_FOUT, "Model saved in file: %s" % save_path)


# define function which creates data batches and feeds them to a built graph for training
def train_one_epoch(sess, ops, train_writer):
    """ ops: dict mapping from string to tf ops """
    is_training = True

    # Shuffle train files
    train_file_idxs = np.arange(0, len(TRAIN_FILES))
    np.random.shuffle(train_file_idxs)  # train_file_idxs will be some random sequence of indexes of train files
    print("train_file_idxs is", train_file_idxs)

    # training within every epoch will be done using 5 train-files
    for fn in range(len(TRAIN_FILES)):
        log_string(LOG_FOUT, 'train file ----' + str(fn) + '-----')
        # train_file_idxs[fn] is some random index of train file.
        # current_data will be 2048 clouds with 2048 (MAX_NUM_POINT) points in each, 3 coors per point
        # current_label will be 2048 clouds with 1 label each
        # current_data, current_label = provider.loadDataFile(TRAIN_FILES[train_file_idxs[fn]])
        current_data, current_label = provider.load_h5(TRAIN_FILES[train_file_idxs[fn]])
        current_data = current_data[:, 0:NUM_POINT, :]  # cut only specified number of points from each cloud
        current_data, current_label, _ = provider.shuffle_data(current_data, np.squeeze(current_label))
        # current_label = np.squeeze(current_label)

        file_size = current_data.shape[0]
        num_batches = file_size // BATCH_SIZE

        total_correct = 0
        total_seen = 0
        loss_sum = 0

        # clouds within every file will be divided into groups of size BATCH_SIZE
        for batch_idx in range(num_batches):
            start_idx = batch_idx * BATCH_SIZE
            end_idx = (batch_idx + 1) * BATCH_SIZE

            # Cut a sequence of BATCH_SIZE clouds from current_data
            # And augment batched point clouds by rotation and jittering
            rotated_data = provider.rotate_point_cloud(current_data[start_idx:end_idx, :, :])
            jittered_data = provider.jitter_point_cloud(rotated_data)
            jittered_data = provider.random_scale_point_cloud(jittered_data)
            jittered_data = provider.rotate_perturbation_point_cloud(jittered_data)
            jittered_data = provider.shift_point_cloud(jittered_data)

            # define dict and perform feeding of this batch
            feed_dict = {ops['pointclouds_pl']: jittered_data,
                         ops['labels_pl']: current_label[start_idx:end_idx],
                         ops['is_training_pl']: is_training, }
            summary, step, _, loss_value, pred_value = sess.run([ops['merged'], ops['step'],
                                                                 ops['train_op'], ops['loss'], ops['pred']],
                                                                feed_dict=feed_dict)
            train_writer.add_summary(summary, step)
            pred_value = np.argmax(pred_value, 1)  # pred_value is argmax of pred_value probabilities on axis 1
            correct = np.sum(pred_value == current_label[start_idx:end_idx])  # number of correct predictions
            total_correct += correct
            total_seen += BATCH_SIZE
            loss_sum += loss_value

        log_string(LOG_FOUT, 'mean loss: %f' % (loss_sum / float(num_batches)))  # mean loss of current epoch
        log_string(LOG_FOUT, 'accuracy: %f' % (
                    total_correct / float(total_seen)))  # accuracy of current epoch. Both numbers count clouds


# define function which creates data batches and feeds them to a built graph for testing
def eval_one_epoch(sess, ops, test_writer):
    """ ops: dict mapping from string to tf ops """
    is_training = False
    total_correct = 0
    total_seen = 0
    loss_sum = 0
    total_seen_class = [0 for _ in range(NUM_CLASSES)]
    total_correct_class = [0 for _ in range(NUM_CLASSES)]

    # evaluation within every epoch will be done using 5 train-files
    for fn in range(len(TEST_FILES)):
        log_string(LOG_FOUT, 'eval file ----' + str(fn) + '-----')
        #current_data, current_label = provider.loadDataFile(TEST_FILES[fn])  # load data and labels from file
        current_data, current_label = provider.load_h5(TEST_FILES[fn])  # load data and labels from file
        current_data = current_data[:, 0:NUM_POINT, :]  # crop only specific number of points from current_data
        current_label = np.squeeze(current_label)  # no need to shuffle, so that's it

        file_size = current_data.shape[0]
        num_batches = file_size // BATCH_SIZE

        # clouds within every file will be divided into groups of size BATCH_SIZE
        for batch_idx in range(num_batches):
            start_idx = batch_idx * BATCH_SIZE
            end_idx = (batch_idx + 1) * BATCH_SIZE

            # define dict and perform feeding of this batch
            feed_dict = {ops['pointclouds_pl']: current_data[start_idx:end_idx, :, :],
                         ops['labels_pl']: current_label[start_idx:end_idx],
                         ops['is_training_pl']: is_training}
            summary, step, loss_value, pred_value = sess.run([ops['merged'], ops['step'],
                                                              ops['loss'], ops['pred']], feed_dict=feed_dict)
            pred_value = np.argmax(pred_value, 1)  # pred_value is argmax of pred_value probabilities on axis 1
            correct = np.sum(pred_value == current_label[start_idx:end_idx])  # number of correct predictions
            total_correct += correct
            total_seen += BATCH_SIZE
            loss_sum += (loss_value * BATCH_SIZE)
            #loss_sum += loss_value
            for i in range(start_idx, end_idx):
                l = current_label[i]
                total_seen_class[l] += 1
                total_correct_class[l] += (pred_value[i - start_idx] == l)

    log_string(LOG_FOUT, 'eval mean loss: %f' % (loss_sum / float(total_seen)))
    #log_string('eval mean loss: %f' % (loss_sum / float(num_batches)))
    log_string(LOG_FOUT, 'eval accuracy: %f' % (total_correct / float(total_seen)))
    log_string(LOG_FOUT, 'eval avg class acc: %f' % (
        np.mean(np.array(total_correct_class) / np.array(total_seen_class, dtype=np.float))))

# %%
if __name__ == "__main__":
    train()
    LOG_FOUT.close()
# Out:
# Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
# WARNING:tensorflow:From /home/kuramin/Diploma/repos/DGCNN_tf/dgcnn-1/tensorflow/utils/tf_util.py:342: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /home/kuramin/Diploma/repos/DGCNN_tf/dgcnn-1/tensorflow/dgcnn.py:51: calling reduce_max (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# **** EPOCH 000 ****
# train_file_idxs is [3 2 4 0 1]
# train file ----0-----
# /home/kuramin/Diploma/repos/DGCNN_tf/dgcnn-1/tensorflow/provider.py:149: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   f = h5py.File(h5_filename)
# mean loss: 3.564339
# accuracy: 0.188235
# train file ----1-----
# mean loss: 3.176361
# accuracy: 0.278431
# train file ----2-----
# mean loss: 2.881954
# accuracy: 0.365196
# train file ----3-----
# mean loss: 2.695330
# accuracy: 0.430882
# train file ----4-----
# mean loss: 2.529665
# accuracy: 0.491667
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 2.225706
# eval accuracy: 0.590686
# eval avg class acc: 0.516813
# Model saved in file: log/model.ckpt
# **** EPOCH 001 ****
# train_file_idxs is [1 3 4 2 0]
# train file ----0-----
# mean loss: 2.409746
# accuracy: 0.545588
# train file ----1-----
# mean loss: 2.319252
# accuracy: 0.582843
# train file ----2-----
# mean loss: 2.255344
# accuracy: 0.599265
# train file ----3-----
# mean loss: 2.224069
# accuracy: 0.635784
# train file ----4-----
# mean loss: 2.216511
# accuracy: 0.624510
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.990084
# eval accuracy: 0.697712
# eval avg class acc: 0.606529
# **** EPOCH 002 ****
# train_file_idxs is [2 3 0 4 1]
# train file ----0-----
# mean loss: 2.139008
# accuracy: 0.649020
# train file ----1-----
# mean loss: 2.085848
# accuracy: 0.682843
# train file ----2-----
# mean loss: 2.096943
# accuracy: 0.673039
# train file ----3-----
# mean loss: 2.041194
# accuracy: 0.691789
# train file ----4-----
# mean loss: 2.038963
# accuracy: 0.694118
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.803801
# eval accuracy: 0.781046
# eval avg class acc: 0.699080
# **** EPOCH 003 ****
# train_file_idxs is [4 2 3 0 1]
# train file ----0-----
# mean loss: 2.007660
# accuracy: 0.702819
# train file ----1-----
# mean loss: 1.996830
# accuracy: 0.712745
# train file ----2-----
# mean loss: 1.988864
# accuracy: 0.724020
# train file ----3-----
# mean loss: 1.973067
# accuracy: 0.731373
# train file ----4-----
# mean loss: 1.956135
# accuracy: 0.724510
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.756820
# eval accuracy: 0.799428
# eval avg class acc: 0.716945
# **** EPOCH 004 ****
# train_file_idxs is [3 4 2 0 1]
# train file ----0-----
# mean loss: 1.936506
# accuracy: 0.751471
# train file ----1-----
# mean loss: 1.896139
# accuracy: 0.763480
# train file ----2-----
# mean loss: 1.931923
# accuracy: 0.741667
# train file ----3-----
# mean loss: 1.913831
# accuracy: 0.744608
# train file ----4-----
# mean loss: 1.899954
# accuracy: 0.757353
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.746482
# eval accuracy: 0.813725
# eval avg class acc: 0.753919
# **** EPOCH 005 ****
# train_file_idxs is [2 3 1 0 4]
# train file ----0-----
# mean loss: 1.895027
# accuracy: 0.763725
# train file ----1-----
# mean loss: 1.870422
# accuracy: 0.767647
# train file ----2-----
# mean loss: 1.874563
# accuracy: 0.768137
# train file ----3-----
# mean loss: 1.859794
# accuracy: 0.777451
# train file ----4-----
# mean loss: 1.824109
# accuracy: 0.787990
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.698515
# eval accuracy: 0.823938
# eval avg class acc: 0.775249
# **** EPOCH 006 ****
# train_file_idxs is [0 2 1 3 4]
# train file ----0-----
# mean loss: 1.840495
# accuracy: 0.785294
# train file ----1-----
# mean loss: 1.833132
# accuracy: 0.785784
# train file ----2-----
# mean loss: 1.858264
# accuracy: 0.776471
# train file ----3-----
# mean loss: 1.806148
# accuracy: 0.801471
# train file ----4-----
# mean loss: 1.792581
# accuracy: 0.799020
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.676128
# eval accuracy: 0.833742
# eval avg class acc: 0.777375
# **** EPOCH 007 ****
# train_file_idxs is [2 0 4 1 3]
# train file ----0-----
# mean loss: 1.811235
# accuracy: 0.789706
# train file ----1-----
# mean loss: 1.810617
# accuracy: 0.786275
# train file ----2-----
# mean loss: 1.789588
# accuracy: 0.801471
# train file ----3-----
# mean loss: 1.807050
# accuracy: 0.788725
# train file ----4-----
# mean loss: 1.793097
# accuracy: 0.806863
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.664550
# eval accuracy: 0.847631
# eval avg class acc: 0.777357
# **** EPOCH 008 ****
# train_file_idxs is [3 1 4 0 2]
# train file ----0-----
# mean loss: 1.771727
# accuracy: 0.808333
# train file ----1-----
# mean loss: 1.786285
# accuracy: 0.802941
# train file ----2-----
# mean loss: 1.759055
# accuracy: 0.816789
# train file ----3-----
# mean loss: 1.785526
# accuracy: 0.799020
# train file ----4-----
# mean loss: 1.775448
# accuracy: 0.810294
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.636672
# eval accuracy: 0.854167
# eval avg class acc: 0.778916
# **** EPOCH 009 ****
# train_file_idxs is [2 4 0 1 3]
# train file ----0-----
# mean loss: 1.758084
# accuracy: 0.825000
# train file ----1-----
# mean loss: 1.744202
# accuracy: 0.822304
# train file ----2-----
# mean loss: 1.762512
# accuracy: 0.811275
# train file ----3-----
# mean loss: 1.768451
# accuracy: 0.820588
# train file ----4-----
# mean loss: 1.757486
# accuracy: 0.824020
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.619718
# eval accuracy: 0.857026
# eval avg class acc: 0.797537
# **** EPOCH 010 ****
# train_file_idxs is [4 0 1 2 3]
# train file ----0-----
# mean loss: 1.707340
# accuracy: 0.840074
# train file ----1-----
# mean loss: 1.742556
# accuracy: 0.821569
# train file ----2-----
# mean loss: 1.753040
# accuracy: 0.820098
# train file ----3-----
# mean loss: 1.745743
# accuracy: 0.819608
# train file ----4-----
# mean loss: 1.727883
# accuracy: 0.824020
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.609354
# eval accuracy: 0.864379
# eval avg class acc: 0.804501
# Model saved in file: log/model.ckpt
# **** EPOCH 011 ****
# train_file_idxs is [4 0 1 2 3]
# train file ----0-----
# mean loss: 1.708139
# accuracy: 0.837623
# train file ----1-----
# mean loss: 1.722393
# accuracy: 0.818137
# train file ----2-----
# mean loss: 1.734115
# accuracy: 0.816176
# train file ----3-----
# mean loss: 1.725414
# accuracy: 0.827941
# train file ----4-----
# mean loss: 1.724791
# accuracy: 0.838235
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.621449
# eval accuracy: 0.870507
# eval avg class acc: 0.819577
# **** EPOCH 012 ****
# train_file_idxs is [1 2 0 4 3]
# train file ----0-----
# mean loss: 1.729480
# accuracy: 0.834314
# train file ----1-----
# mean loss: 1.713493
# accuracy: 0.831863
# train file ----2-----
# mean loss: 1.716565
# accuracy: 0.828431
# train file ----3-----
# mean loss: 1.705309
# accuracy: 0.835172
# train file ----4-----
# mean loss: 1.696162
# accuracy: 0.839706
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.590257
# eval accuracy: 0.862337
# eval avg class acc: 0.805742
# **** EPOCH 013 ****
# train_file_idxs is [1 2 0 3 4]
# train file ----0-----
# mean loss: 1.715362
# accuracy: 0.827941
# train file ----1-----
# mean loss: 1.698511
# accuracy: 0.839706
# train file ----2-----
# mean loss: 1.696512
# accuracy: 0.844118
# train file ----3-----
# mean loss: 1.703141
# accuracy: 0.836765
# train file ----4-----
# mean loss: 1.680746
# accuracy: 0.856005
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.592034
# eval accuracy: 0.870098
# eval avg class acc: 0.820050
# **** EPOCH 014 ****
# train_file_idxs is [1 2 0 4 3]
# train file ----0-----
# mean loss: 1.691189
# accuracy: 0.845588
# train file ----1-----
# mean loss: 1.704184
# accuracy: 0.832843
# train file ----2-----
# mean loss: 1.689616
# accuracy: 0.841667
# train file ----3-----
# mean loss: 1.671830
# accuracy: 0.845588
# train file ----4-----
# mean loss: 1.678454
# accuracy: 0.846569
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.597714
# eval accuracy: 0.865196
# eval avg class acc: 0.817575
# **** EPOCH 015 ****
# train_file_idxs is [2 3 0 1 4]
# train file ----0-----
# mean loss: 1.680642
# accuracy: 0.857843
# train file ----1-----
# mean loss: 1.656094
# accuracy: 0.854412
# train file ----2-----
# mean loss: 1.679879
# accuracy: 0.841176
# train file ----3-----
# mean loss: 1.688270
# accuracy: 0.851961
# train file ----4-----
# mean loss: 1.669641
# accuracy: 0.852941
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.580241
# eval accuracy: 0.873366
# eval avg class acc: 0.837732
# **** EPOCH 016 ****
# train_file_idxs is [3 0 2 4 1]
# train file ----0-----
# mean loss: 1.666820
# accuracy: 0.858333
# train file ----1-----
# mean loss: 1.674052
# accuracy: 0.848039
# train file ----2-----
# mean loss: 1.672921
# accuracy: 0.853922
# train file ----3-----
# mean loss: 1.640537
# accuracy: 0.871324
# train file ----4-----
# mean loss: 1.678920
# accuracy: 0.846078
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.598657
# eval accuracy: 0.874592
# eval avg class acc: 0.828921
# **** EPOCH 017 ****
# train_file_idxs is [4 3 1 0 2]
# train file ----0-----
# mean loss: 1.618804
# accuracy: 0.871324
# train file ----1-----
# mean loss: 1.656243
# accuracy: 0.854412
# train file ----2-----
# mean loss: 1.667702
# accuracy: 0.857843
# train file ----3-----
# mean loss: 1.656534
# accuracy: 0.853922
# train file ----4-----
# mean loss: 1.670900
# accuracy: 0.854412
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.555554
# eval accuracy: 0.882761
# eval avg class acc: 0.830617
# **** EPOCH 018 ****
# train_file_idxs is [2 1 3 4 0]
# train file ----0-----
# mean loss: 1.640860
# accuracy: 0.858824
# train file ----1-----
# mean loss: 1.680612
# accuracy: 0.838725
# train file ----2-----
# mean loss: 1.658591
# accuracy: 0.856373
# train file ----3-----
# mean loss: 1.634266
# accuracy: 0.867647
# train file ----4-----
# mean loss: 1.661254
# accuracy: 0.848039
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.555325
# eval accuracy: 0.877859
# eval avg class acc: 0.817047
# **** EPOCH 019 ****
# train_file_idxs is [1 2 0 3 4]
# train file ----0-----
# mean loss: 1.644556
# accuracy: 0.862255
# train file ----1-----
# mean loss: 1.650434
# accuracy: 0.863725
# train file ----2-----
# mean loss: 1.644236
# accuracy: 0.856373
# train file ----3-----
# mean loss: 1.647018
# accuracy: 0.861275
# train file ----4-----
# mean loss: 1.640304
# accuracy: 0.866422
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.571194
# eval accuracy: 0.863154
# eval avg class acc: 0.824024
# **** EPOCH 020 ****
# train_file_idxs is [1 4 0 2 3]
# train file ----0-----
# mean loss: 1.654989
# accuracy: 0.856863
# train file ----1-----
# mean loss: 1.625007
# accuracy: 0.869485
# train file ----2-----
# mean loss: 1.634106
# accuracy: 0.859804
# train file ----3-----
# mean loss: 1.630989
# accuracy: 0.870588
# train file ----4-----
# mean loss: 1.625971
# accuracy: 0.871569
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.528657
# eval accuracy: 0.889706
# eval avg class acc: 0.848609
# Model saved in file: log/model.ckpt
# **** EPOCH 021 ****
# train_file_idxs is [1 0 2 3 4]
# train file ----0-----
# mean loss: 1.628463
# accuracy: 0.868137
# train file ----1-----
# mean loss: 1.618877
# accuracy: 0.873039
# train file ----2-----
# mean loss: 1.606641
# accuracy: 0.885294
# train file ----3-----
# mean loss: 1.613424
# accuracy: 0.880392
# train file ----4-----
# mean loss: 1.603560
# accuracy: 0.876838
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.542230
# eval accuracy: 0.880310
# eval avg class acc: 0.845244
# **** EPOCH 022 ****
# train_file_idxs is [2 0 3 4 1]
# train file ----0-----
# mean loss: 1.590394
# accuracy: 0.883333
# train file ----1-----
# mean loss: 1.599927
# accuracy: 0.885294
# train file ----2-----
# mean loss: 1.599136
# accuracy: 0.878431
# train file ----3-----
# mean loss: 1.594530
# accuracy: 0.882353
# train file ----4-----
# mean loss: 1.613440
# accuracy: 0.869608
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.524323
# eval accuracy: 0.890523
# eval avg class acc: 0.833512
# **** EPOCH 023 ****
# train_file_idxs is [4 1 2 3 0]
# train file ----0-----
# mean loss: 1.578577
# accuracy: 0.885417
# train file ----1-----
# mean loss: 1.601044
# accuracy: 0.875980
# train file ----2-----
# mean loss: 1.602192
# accuracy: 0.880882
# train file ----3-----
# mean loss: 1.603681
# accuracy: 0.872549
# train file ----4-----
# mean loss: 1.592853
# accuracy: 0.876961
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.506884
# eval accuracy: 0.896650
# eval avg class acc: 0.849707
# **** EPOCH 024 ****
# train_file_idxs is [2 3 0 4 1]
# train file ----0-----
# mean loss: 1.592094
# accuracy: 0.882843
# train file ----1-----
# mean loss: 1.590677
# accuracy: 0.884314
# train file ----2-----
# mean loss: 1.591867
# accuracy: 0.882843
# train file ----3-----
# mean loss: 1.585673
# accuracy: 0.883578
# train file ----4-----
# mean loss: 1.618159
# accuracy: 0.878431
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.513420
# eval accuracy: 0.895425
# eval avg class acc: 0.849472
# **** EPOCH 025 ****
# train_file_idxs is [1 3 4 0 2]
# train file ----0-----
# mean loss: 1.580690
# accuracy: 0.885294
# train file ----1-----
# mean loss: 1.579860
# accuracy: 0.890196
# train file ----2-----
# mean loss: 1.581324
# accuracy: 0.882966
# train file ----3-----
# mean loss: 1.580924
# accuracy: 0.879902
# train file ----4-----
# mean loss: 1.598685
# accuracy: 0.875980
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.509899
# eval accuracy: 0.885621
# eval avg class acc: 0.842998
# **** EPOCH 026 ****
# train_file_idxs is [0 2 1 3 4]
# train file ----0-----
# mean loss: 1.572785
# accuracy: 0.891176
# train file ----1-----
# mean loss: 1.582607
# accuracy: 0.886765
# train file ----2-----
# mean loss: 1.582764
# accuracy: 0.885294
# train file ----3-----
# mean loss: 1.585081
# accuracy: 0.888235
# train file ----4-----
# mean loss: 1.569189
# accuracy: 0.888480
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.520480
# eval accuracy: 0.886438
# eval avg class acc: 0.857562
# **** EPOCH 027 ****
# train_file_idxs is [2 4 1 0 3]
# train file ----0-----
# mean loss: 1.589502
# accuracy: 0.884804
# train file ----1-----
# mean loss: 1.560214
# accuracy: 0.894608
# train file ----2-----
# mean loss: 1.599428
# accuracy: 0.873529
# train file ----3-----
# mean loss: 1.568691
# accuracy: 0.893627
# train file ----4-----
# mean loss: 1.583137
# accuracy: 0.889706
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.518722
# eval accuracy: 0.891340
# eval avg class acc: 0.852035
# **** EPOCH 028 ****
# train_file_idxs is [4 0 1 2 3]
# train file ----0-----
# mean loss: 1.575367
# accuracy: 0.896446
# train file ----1-----
# mean loss: 1.564565
# accuracy: 0.895588
# train file ----2-----
# mean loss: 1.581540
# accuracy: 0.890686
# train file ----3-----
# mean loss: 1.568645
# accuracy: 0.892647
# train file ----4-----
# mean loss: 1.584054
# accuracy: 0.885294
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.522346
# eval accuracy: 0.885212
# eval avg class acc: 0.842672
# **** EPOCH 029 ****
# train_file_idxs is [0 4 2 1 3]
# train file ----0-----
# mean loss: 1.566352
# accuracy: 0.888725
# train file ----1-----
# mean loss: 1.559284
# accuracy: 0.899510
# train file ----2-----
# mean loss: 1.566168
# accuracy: 0.890196
# train file ----3-----
# mean loss: 1.574572
# accuracy: 0.889216
# train file ----4-----
# mean loss: 1.561282
# accuracy: 0.896078
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.517016
# eval accuracy: 0.890523
# eval avg class acc: 0.846414
# **** EPOCH 030 ****
# train_file_idxs is [4 3 1 0 2]
# train file ----0-----
# mean loss: 1.566926
# accuracy: 0.890931
# train file ----1-----
# mean loss: 1.548557
# accuracy: 0.898039
# train file ----2-----
# mean loss: 1.585507
# accuracy: 0.882353
# train file ----3-----
# mean loss: 1.563467
# accuracy: 0.893137
# train file ----4-----
# mean loss: 1.568517
# accuracy: 0.887745
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.492148
# eval accuracy: 0.899918
# eval avg class acc: 0.858250
# Model saved in file: log/model.ckpt
# **** EPOCH 031 ****
# train_file_idxs is [2 3 4 0 1]
# train file ----0-----
# mean loss: 1.561652
# accuracy: 0.900980
# train file ----1-----
# mean loss: 1.557307
# accuracy: 0.898039
# train file ----2-----
# mean loss: 1.556292
# accuracy: 0.896446
# train file ----3-----
# mean loss: 1.568798
# accuracy: 0.891176
# train file ----4-----
# mean loss: 1.571304
# accuracy: 0.892157
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.495475
# eval accuracy: 0.898693
# eval avg class acc: 0.852159
# **** EPOCH 032 ****
# train_file_idxs is [3 2 4 0 1]
# train file ----0-----
# mean loss: 1.545659
# accuracy: 0.904412
# train file ----1-----
# mean loss: 1.559774
# accuracy: 0.900490
# train file ----2-----
# mean loss: 1.546832
# accuracy: 0.898897
# train file ----3-----
# mean loss: 1.541378
# accuracy: 0.907353
# train file ----4-----
# mean loss: 1.576601
# accuracy: 0.894118
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.512329
# eval accuracy: 0.886029
# eval avg class acc: 0.843513
# **** EPOCH 033 ****
# train_file_idxs is [4 1 2 3 0]
# train file ----0-----
# mean loss: 1.540848
# accuracy: 0.903799
# train file ----1-----
# mean loss: 1.545877
# accuracy: 0.908824
# train file ----2-----
# mean loss: 1.557892
# accuracy: 0.900000
# train file ----3-----
# mean loss: 1.557139
# accuracy: 0.900490
# train file ----4-----
# mean loss: 1.565516
# accuracy: 0.888235
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.510928
# eval accuracy: 0.881536
# eval avg class acc: 0.846672
# **** EPOCH 034 ****
# train_file_idxs is [0 4 2 1 3]
# train file ----0-----
# mean loss: 1.524503
# accuracy: 0.915686
# train file ----1-----
# mean loss: 1.540859
# accuracy: 0.899510
# train file ----2-----
# mean loss: 1.573040
# accuracy: 0.887255
# train file ----3-----
# mean loss: 1.557981
# accuracy: 0.893137
# train file ----4-----
# mean loss: 1.562428
# accuracy: 0.891667
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.503339
# eval accuracy: 0.888889
# eval avg class acc: 0.848052
# **** EPOCH 035 ****
# train_file_idxs is [4 0 1 3 2]
# train file ----0-----
# mean loss: 1.540425
# accuracy: 0.903799
# train file ----1-----
# mean loss: 1.544385
# accuracy: 0.903922
# train file ----2-----
# mean loss: 1.567756
# accuracy: 0.893137
# train file ----3-----
# mean loss: 1.553367
# accuracy: 0.902941
# train file ----4-----
# mean loss: 1.554902
# accuracy: 0.902941
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.498260
# eval accuracy: 0.892565
# eval avg class acc: 0.851755
# **** EPOCH 036 ****
# train_file_idxs is [0 1 4 2 3]
# train file ----0-----
# mean loss: 1.543691
# accuracy: 0.907843
# train file ----1-----
# mean loss: 1.552477
# accuracy: 0.898529
# train file ----2-----
# mean loss: 1.548424
# accuracy: 0.905637
# train file ----3-----
# mean loss: 1.552231
# accuracy: 0.900490
# train file ----4-----
# mean loss: 1.558301
# accuracy: 0.898039
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.495764
# eval accuracy: 0.890523
# eval avg class acc: 0.844881
# **** EPOCH 037 ****
# train_file_idxs is [1 0 4 3 2]
# train file ----0-----
# mean loss: 1.550315
# accuracy: 0.901471
# train file ----1-----
# mean loss: 1.548205
# accuracy: 0.906863
# train file ----2-----
# mean loss: 1.533852
# accuracy: 0.905025
# train file ----3-----
# mean loss: 1.553622
# accuracy: 0.900490
# train file ----4-----
# mean loss: 1.545538
# accuracy: 0.905882
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.511370
# eval accuracy: 0.882353
# eval avg class acc: 0.838508
# **** EPOCH 038 ****
# train_file_idxs is [3 0 2 4 1]
# train file ----0-----
# mean loss: 1.534495
# accuracy: 0.905882
# train file ----1-----
# mean loss: 1.548264
# accuracy: 0.897549
# train file ----2-----
# mean loss: 1.545371
# accuracy: 0.905392
# train file ----3-----
# mean loss: 1.535534
# accuracy: 0.902574
# train file ----4-----
# mean loss: 1.548697
# accuracy: 0.898039
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.493585
# eval accuracy: 0.898693
# eval avg class acc: 0.852746
# **** EPOCH 039 ****
# train_file_idxs is [3 1 4 2 0]
# train file ----0-----
# mean loss: 1.543233
# accuracy: 0.901471
# train file ----1-----
# mean loss: 1.532617
# accuracy: 0.907843
# train file ----2-----
# mean loss: 1.535217
# accuracy: 0.908088
# train file ----3-----
# mean loss: 1.544504
# accuracy: 0.903431
# train file ----4-----
# mean loss: 1.555541
# accuracy: 0.893137
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.498586
# eval accuracy: 0.900327
# eval avg class acc: 0.869360
# **** EPOCH 040 ****
# train_file_idxs is [1 4 2 0 3]
# train file ----0-----
# mean loss: 1.532686
# accuracy: 0.912255
# train file ----1-----
# mean loss: 1.532245
# accuracy: 0.909314
# train file ----2-----
# mean loss: 1.544226
# accuracy: 0.905882
# train file ----3-----
# mean loss: 1.542839
# accuracy: 0.895588
# train file ----4-----
# mean loss: 1.534679
# accuracy: 0.908824
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.485441
# eval accuracy: 0.896242
# eval avg class acc: 0.857412
# Model saved in file: log/model.ckpt
# **** EPOCH 041 ****
# train_file_idxs is [2 1 4 0 3]
# train file ----0-----
# mean loss: 1.524624
# accuracy: 0.905392
# train file ----1-----
# mean loss: 1.530639
# accuracy: 0.911275
# train file ----2-----
# mean loss: 1.524393
# accuracy: 0.909314
# train file ----3-----
# mean loss: 1.522843
# accuracy: 0.907843
# train file ----4-----
# mean loss: 1.523634
# accuracy: 0.913235
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.484543
# eval accuracy: 0.892974
# eval avg class acc: 0.846798
# **** EPOCH 042 ****
# train_file_idxs is [3 1 4 0 2]
# train file ----0-----
# mean loss: 1.513153
# accuracy: 0.920098
# train file ----1-----
# mean loss: 1.514068
# accuracy: 0.920588
# train file ----2-----
# mean loss: 1.514980
# accuracy: 0.917279
# train file ----3-----
# mean loss: 1.511116
# accuracy: 0.913235
# train file ----4-----
# mean loss: 1.522096
# accuracy: 0.902941
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.486528
# eval accuracy: 0.897059
# eval avg class acc: 0.857928
# **** EPOCH 043 ****
# train_file_idxs is [2 3 4 1 0]
# train file ----0-----
# mean loss: 1.491968
# accuracy: 0.929412
# train file ----1-----
# mean loss: 1.512446
# accuracy: 0.910784
# train file ----2-----
# mean loss: 1.505749
# accuracy: 0.914828
# train file ----3-----
# mean loss: 1.527588
# accuracy: 0.912255
# train file ----4-----
# mean loss: 1.520067
# accuracy: 0.907353
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.481446
# eval accuracy: 0.898284
# eval avg class acc: 0.857660
# **** EPOCH 044 ****
# train_file_idxs is [2 0 4 1 3]
# train file ----0-----
# mean loss: 1.520008
# accuracy: 0.907843
# train file ----1-----
# mean loss: 1.500256
# accuracy: 0.924510
# train file ----2-----
# mean loss: 1.508861
# accuracy: 0.920956
# train file ----3-----
# mean loss: 1.517754
# accuracy: 0.914216
# train file ----4-----
# mean loss: 1.522592
# accuracy: 0.903431
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.483913
# eval accuracy: 0.887663
# eval avg class acc: 0.861105
# **** EPOCH 045 ****
# train_file_idxs is [4 2 3 1 0]
# train file ----0-----
# mean loss: 1.515259
# accuracy: 0.916667
# train file ----1-----
# mean loss: 1.509360
# accuracy: 0.915686
# train file ----2-----
# mean loss: 1.512079
# accuracy: 0.916176
# train file ----3-----
# mean loss: 1.517776
# accuracy: 0.915686
# train file ----4-----
# mean loss: 1.509023
# accuracy: 0.915686
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.474703
# eval accuracy: 0.899510
# eval avg class acc: 0.863258
# **** EPOCH 046 ****
# train_file_idxs is [4 2 3 0 1]
# train file ----0-----
# mean loss: 1.508292
# accuracy: 0.923407
# train file ----1-----
# mean loss: 1.503203
# accuracy: 0.918137
# train file ----2-----
# mean loss: 1.500241
# accuracy: 0.916176
# train file ----3-----
# mean loss: 1.513687
# accuracy: 0.914706
# train file ----4-----
# mean loss: 1.507582
# accuracy: 0.911275
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.479228
# eval accuracy: 0.892974
# eval avg class acc: 0.855671
# **** EPOCH 047 ****
# train_file_idxs is [3 1 0 2 4]
# train file ----0-----
# mean loss: 1.509930
# accuracy: 0.917157
# train file ----1-----
# mean loss: 1.500753
# accuracy: 0.922059
# train file ----2-----
# mean loss: 1.501454
# accuracy: 0.915686
# train file ----3-----
# mean loss: 1.507994
# accuracy: 0.917647
# train file ----4-----
# mean loss: 1.505067
# accuracy: 0.912377
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.482375
# eval accuracy: 0.900327
# eval avg class acc: 0.869855
# **** EPOCH 048 ****
# train_file_idxs is [1 3 4 2 0]
# train file ----0-----
# mean loss: 1.508925
# accuracy: 0.919608
# train file ----1-----
# mean loss: 1.495928
# accuracy: 0.931373
# train file ----2-----
# mean loss: 1.483649
# accuracy: 0.928309
# train file ----3-----
# mean loss: 1.520049
# accuracy: 0.911275
# train file ----4-----
# mean loss: 1.503797
# accuracy: 0.917157
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.476178
# eval accuracy: 0.899101
# eval avg class acc: 0.869743
# **** EPOCH 049 ****
# train_file_idxs is [0 1 4 2 3]
# train file ----0-----
# mean loss: 1.497762
# accuracy: 0.927941
# train file ----1-----
# mean loss: 1.511511
# accuracy: 0.916176
# train file ----2-----
# mean loss: 1.493220
# accuracy: 0.928309
# train file ----3-----
# mean loss: 1.508703
# accuracy: 0.919118
# train file ----4-----
# mean loss: 1.503855
# accuracy: 0.919118
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.478914
# eval accuracy: 0.891748
# eval avg class acc: 0.854575
# **** EPOCH 050 ****
# train_file_idxs is [0 3 1 4 2]
# train file ----0-----
# mean loss: 1.498496
# accuracy: 0.921569
# train file ----1-----
# mean loss: 1.492652
# accuracy: 0.918137
# train file ----2-----
# mean loss: 1.494177
# accuracy: 0.920588
# train file ----3-----
# mean loss: 1.494418
# accuracy: 0.924632
# train file ----4-----
# mean loss: 1.504230
# accuracy: 0.922059
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.479716
# eval accuracy: 0.898284
# eval avg class acc: 0.863572
# Model saved in file: log/model.ckpt
# **** EPOCH 051 ****
# train_file_idxs is [1 3 0 2 4]
# train file ----0-----
# mean loss: 1.502216
# accuracy: 0.919608
# train file ----1-----
# mean loss: 1.506298
# accuracy: 0.916667
# train file ----2-----
# mean loss: 1.500407
# accuracy: 0.920588
# train file ----3-----
# mean loss: 1.506767
# accuracy: 0.920588
# train file ----4-----
# mean loss: 1.493347
# accuracy: 0.931373
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.478546
# eval accuracy: 0.894199
# eval avg class acc: 0.864893
# **** EPOCH 052 ****
# train_file_idxs is [3 4 2 1 0]
# train file ----0-----
# mean loss: 1.497125
# accuracy: 0.925980
# train file ----1-----
# mean loss: 1.475272
# accuracy: 0.931985
# train file ----2-----
# mean loss: 1.507135
# accuracy: 0.918137
# train file ----3-----
# mean loss: 1.494829
# accuracy: 0.922059
# train file ----4-----
# mean loss: 1.501017
# accuracy: 0.920098
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.476872
# eval accuracy: 0.892974
# eval avg class acc: 0.855515
# **** EPOCH 053 ****
# train_file_idxs is [0 1 4 2 3]
# train file ----0-----
# mean loss: 1.499498
# accuracy: 0.918137
# train file ----1-----
# mean loss: 1.489464
# accuracy: 0.925490
# train file ----2-----
# mean loss: 1.489710
# accuracy: 0.924020
# train file ----3-----
# mean loss: 1.501398
# accuracy: 0.915686
# train file ----4-----
# mean loss: 1.500025
# accuracy: 0.920588
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.479000
# eval accuracy: 0.894199
# eval avg class acc: 0.861704
# **** EPOCH 054 ****
# train_file_idxs is [3 1 2 0 4]
# train file ----0-----
# mean loss: 1.478578
# accuracy: 0.929412
# train file ----1-----
# mean loss: 1.495830
# accuracy: 0.922059
# train file ----2-----
# mean loss: 1.490230
# accuracy: 0.925000
# train file ----3-----
# mean loss: 1.494074
# accuracy: 0.921569
# train file ----4-----
# mean loss: 1.475608
# accuracy: 0.930760
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.476366
# eval accuracy: 0.898284
# eval avg class acc: 0.859060
# **** EPOCH 055 ****
# train_file_idxs is [3 0 4 2 1]
# train file ----0-----
# mean loss: 1.492922
# accuracy: 0.926961
# train file ----1-----
# mean loss: 1.487511
# accuracy: 0.922549
# train file ----2-----
# mean loss: 1.490822
# accuracy: 0.924632
# train file ----3-----
# mean loss: 1.492248
# accuracy: 0.925980
# train file ----4-----
# mean loss: 1.499218
# accuracy: 0.917647
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.483034
# eval accuracy: 0.894199
# eval avg class acc: 0.858077
# **** EPOCH 056 ****
# train_file_idxs is [2 3 0 1 4]
# train file ----0-----
# mean loss: 1.479853
# accuracy: 0.928922
# train file ----1-----
# mean loss: 1.484515
# accuracy: 0.923039
# train file ----2-----
# mean loss: 1.478687
# accuracy: 0.932843
# train file ----3-----
# mean loss: 1.486309
# accuracy: 0.928431
# train file ----4-----
# mean loss: 1.478891
# accuracy: 0.933824
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.481254
# eval accuracy: 0.895425
# eval avg class acc: 0.865522
# **** EPOCH 057 ****
# train_file_idxs is [2 1 4 0 3]
# train file ----0-----
# mean loss: 1.492586
# accuracy: 0.925490
# train file ----1-----
# mean loss: 1.497854
# accuracy: 0.927941
# train file ----2-----
# mean loss: 1.481168
# accuracy: 0.930147
# train file ----3-----
# mean loss: 1.481663
# accuracy: 0.931863
# train file ----4-----
# mean loss: 1.491266
# accuracy: 0.917157
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.472006
# eval accuracy: 0.896242
# eval avg class acc: 0.865879
# **** EPOCH 058 ****
# train_file_idxs is [3 1 2 4 0]
# train file ----0-----
# mean loss: 1.478415
# accuracy: 0.926961
# train file ----1-----
# mean loss: 1.479415
# accuracy: 0.927941
# train file ----2-----
# mean loss: 1.491071
# accuracy: 0.919608
# train file ----3-----
# mean loss: 1.494244
# accuracy: 0.919730
# train file ----4-----
# mean loss: 1.485443
# accuracy: 0.928922
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.470953
# eval accuracy: 0.897467
# eval avg class acc: 0.858843
# **** EPOCH 059 ****
# train_file_idxs is [0 4 1 3 2]
# train file ----0-----
# mean loss: 1.474516
# accuracy: 0.931863
# train file ----1-----
# mean loss: 1.470147
# accuracy: 0.938725
# train file ----2-----
# mean loss: 1.485202
# accuracy: 0.927451
# train file ----3-----
# mean loss: 1.486030
# accuracy: 0.930392
# train file ----4-----
# mean loss: 1.487663
# accuracy: 0.923529
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.470082
# eval accuracy: 0.903186
# eval avg class acc: 0.868621
# **** EPOCH 060 ****
# train_file_idxs is [4 0 3 1 2]
# train file ----0-----
# mean loss: 1.476241
# accuracy: 0.928922
# train file ----1-----
# mean loss: 1.476559
# accuracy: 0.926471
# train file ----2-----
# mean loss: 1.486967
# accuracy: 0.922549
# train file ----3-----
# mean loss: 1.489406
# accuracy: 0.922059
# train file ----4-----
# mean loss: 1.480362
# accuracy: 0.928922
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.472100
# eval accuracy: 0.898284
# eval avg class acc: 0.859484
# Model saved in file: log/model.ckpt
# **** EPOCH 061 ****
# train_file_idxs is [1 4 2 0 3]
# train file ----0-----
# mean loss: 1.486323
# accuracy: 0.930882
# train file ----1-----
# mean loss: 1.483407
# accuracy: 0.923407
# train file ----2-----
# mean loss: 1.477793
# accuracy: 0.926961
# train file ----3-----
# mean loss: 1.471055
# accuracy: 0.931863
# train file ----4-----
# mean loss: 1.480188
# accuracy: 0.929902
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.471012
# eval accuracy: 0.890523
# eval avg class acc: 0.849526
# **** EPOCH 062 ****
# train_file_idxs is [0 4 2 1 3]
# train file ----0-----
# mean loss: 1.465347
# accuracy: 0.927941
# train file ----1-----
# mean loss: 1.466725
# accuracy: 0.939338
# train file ----2-----
# mean loss: 1.476250
# accuracy: 0.927451
# train file ----3-----
# mean loss: 1.471061
# accuracy: 0.930392
# train file ----4-----
# mean loss: 1.469987
# accuracy: 0.934804
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.470644
# eval accuracy: 0.896242
# eval avg class acc: 0.857043
# **** EPOCH 063 ****
# train_file_idxs is [1 2 3 4 0]
# train file ----0-----
# mean loss: 1.467430
# accuracy: 0.936765
# train file ----1-----
# mean loss: 1.465302
# accuracy: 0.939706
# train file ----2-----
# mean loss: 1.467324
# accuracy: 0.933824
# train file ----3-----
# mean loss: 1.458904
# accuracy: 0.932598
# train file ----4-----
# mean loss: 1.475229
# accuracy: 0.929902
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.464298
# eval accuracy: 0.896242
# eval avg class acc: 0.861099
# **** EPOCH 064 ****
# train_file_idxs is [0 3 2 4 1]
# train file ----0-----
# mean loss: 1.469912
# accuracy: 0.939216
# train file ----1-----
# mean loss: 1.459556
# accuracy: 0.938235
# train file ----2-----
# mean loss: 1.464056
# accuracy: 0.932843
# train file ----3-----
# mean loss: 1.452225
# accuracy: 0.935049
# train file ----4-----
# mean loss: 1.473600
# accuracy: 0.923039
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.473034
# eval accuracy: 0.898284
# eval avg class acc: 0.871072
# **** EPOCH 065 ****
# train_file_idxs is [0 3 4 2 1]
# train file ----0-----
# mean loss: 1.461600
# accuracy: 0.934314
# train file ----1-----
# mean loss: 1.454503
# accuracy: 0.942647
# train file ----2-----
# mean loss: 1.463382
# accuracy: 0.933211
# train file ----3-----
# mean loss: 1.462179
# accuracy: 0.931863
# train file ----4-----
# mean loss: 1.475874
# accuracy: 0.931373
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.457295
# eval accuracy: 0.903186
# eval avg class acc: 0.861667
# **** EPOCH 066 ****
# train_file_idxs is [1 2 4 3 0]
# train file ----0-----
# mean loss: 1.457560
# accuracy: 0.944118
# train file ----1-----
# mean loss: 1.467655
# accuracy: 0.929902
# train file ----2-----
# mean loss: 1.471108
# accuracy: 0.933824
# train file ----3-----
# mean loss: 1.471167
# accuracy: 0.932843
# train file ----4-----
# mean loss: 1.472902
# accuracy: 0.933333
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.457743
# eval accuracy: 0.904003
# eval avg class acc: 0.876862
# **** EPOCH 067 ****
# train_file_idxs is [3 1 4 2 0]
# train file ----0-----
# mean loss: 1.459449
# accuracy: 0.938725
# train file ----1-----
# mean loss: 1.465779
# accuracy: 0.934314
# train file ----2-----
# mean loss: 1.448482
# accuracy: 0.938725
# train file ----3-----
# mean loss: 1.462256
# accuracy: 0.935294
# train file ----4-----
# mean loss: 1.466913
# accuracy: 0.929412
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.463166
# eval accuracy: 0.902369
# eval avg class acc: 0.868472
# **** EPOCH 068 ****
# train_file_idxs is [4 0 3 2 1]
# train file ----0-----
# mean loss: 1.450183
# accuracy: 0.938725
# train file ----1-----
# mean loss: 1.453522
# accuracy: 0.939706
# train file ----2-----
# mean loss: 1.466607
# accuracy: 0.936765
# train file ----3-----
# mean loss: 1.470460
# accuracy: 0.932353
# train file ----4-----
# mean loss: 1.462001
# accuracy: 0.933824
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.468258
# eval accuracy: 0.901552
# eval avg class acc: 0.868440
# **** EPOCH 069 ****
# train_file_idxs is [1 4 3 2 0]
# train file ----0-----
# mean loss: 1.460698
# accuracy: 0.940196
# train file ----1-----
# mean loss: 1.469759
# accuracy: 0.925245
# train file ----2-----
# mean loss: 1.459329
# accuracy: 0.940686
# train file ----3-----
# mean loss: 1.469024
# accuracy: 0.929412
# train file ----4-----
# mean loss: 1.466122
# accuracy: 0.934314
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.462903
# eval accuracy: 0.892974
# eval avg class acc: 0.858594
# **** EPOCH 070 ****
# train_file_idxs is [2 4 1 3 0]
# train file ----0-----
# mean loss: 1.463942
# accuracy: 0.941667
# train file ----1-----
# mean loss: 1.458223
# accuracy: 0.941176
# train file ----2-----
# mean loss: 1.463415
# accuracy: 0.936275
# train file ----3-----
# mean loss: 1.467188
# accuracy: 0.934314
# train file ----4-----
# mean loss: 1.458283
# accuracy: 0.939216
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.461835
# eval accuracy: 0.899101
# eval avg class acc: 0.863955
# Model saved in file: log/model.ckpt
# **** EPOCH 071 ****
# train_file_idxs is [2 0 3 1 4]
# train file ----0-----
# mean loss: 1.446869
# accuracy: 0.944608
# train file ----1-----
# mean loss: 1.467108
# accuracy: 0.930392
# train file ----2-----
# mean loss: 1.463521
# accuracy: 0.933824
# train file ----3-----
# mean loss: 1.453870
# accuracy: 0.934314
# train file ----4-----
# mean loss: 1.468909
# accuracy: 0.931373
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.467427
# eval accuracy: 0.897467
# eval avg class acc: 0.868040
# **** EPOCH 072 ****
# train_file_idxs is [0 2 4 3 1]
# train file ----0-----
# mean loss: 1.451202
# accuracy: 0.936765
# train file ----1-----
# mean loss: 1.450399
# accuracy: 0.939706
# train file ----2-----
# mean loss: 1.454736
# accuracy: 0.938725
# train file ----3-----
# mean loss: 1.450698
# accuracy: 0.943627
# train file ----4-----
# mean loss: 1.467986
# accuracy: 0.935784
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.464649
# eval accuracy: 0.902778
# eval avg class acc: 0.874163
# **** EPOCH 073 ****
# train_file_idxs is [1 2 3 4 0]
# train file ----0-----
# mean loss: 1.446195
# accuracy: 0.941667
# train file ----1-----
# mean loss: 1.462287
# accuracy: 0.937745
# train file ----2-----
# mean loss: 1.455748
# accuracy: 0.934804
# train file ----3-----
# mean loss: 1.462001
# accuracy: 0.935049
# train file ----4-----
# mean loss: 1.450383
# accuracy: 0.944118
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.460925
# eval accuracy: 0.899510
# eval avg class acc: 0.862033
# **** EPOCH 074 ****
# train_file_idxs is [3 0 1 2 4]
# train file ----0-----
# mean loss: 1.450163
# accuracy: 0.936275
# train file ----1-----
# mean loss: 1.454850
# accuracy: 0.932843
# train file ----2-----
# mean loss: 1.461774
# accuracy: 0.935294
# train file ----3-----
# mean loss: 1.445860
# accuracy: 0.942157
# train file ----4-----
# mean loss: 1.448414
# accuracy: 0.934436
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.460813
# eval accuracy: 0.897059
# eval avg class acc: 0.868038
# **** EPOCH 075 ****
# train_file_idxs is [0 1 3 2 4]
# train file ----0-----
# mean loss: 1.456570
# accuracy: 0.939706
# train file ----1-----
# mean loss: 1.452143
# accuracy: 0.941176
# train file ----2-----
# mean loss: 1.444774
# accuracy: 0.945098
# train file ----3-----
# mean loss: 1.463505
# accuracy: 0.938725
# train file ----4-----
# mean loss: 1.442244
# accuracy: 0.945466
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.458482
# eval accuracy: 0.900735
# eval avg class acc: 0.862945
# **** EPOCH 076 ****
# train_file_idxs is [4 0 1 2 3]
# train file ----0-----
# mean loss: 1.440891
# accuracy: 0.947304
# train file ----1-----
# mean loss: 1.446882
# accuracy: 0.943137
# train file ----2-----
# mean loss: 1.456776
# accuracy: 0.939216
# train file ----3-----
# mean loss: 1.452656
# accuracy: 0.940196
# train file ----4-----
# mean loss: 1.449315
# accuracy: 0.939706
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.452309
# eval accuracy: 0.901552
# eval avg class acc: 0.866203
# **** EPOCH 077 ****
# train_file_idxs is [4 1 2 3 0]
# train file ----0-----
# mean loss: 1.445730
# accuracy: 0.938113
# train file ----1-----
# mean loss: 1.451631
# accuracy: 0.943627
# train file ----2-----
# mean loss: 1.448873
# accuracy: 0.941667
# train file ----3-----
# mean loss: 1.453899
# accuracy: 0.936275
# train file ----4-----
# mean loss: 1.446667
# accuracy: 0.943627
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.451342
# eval accuracy: 0.901144
# eval avg class acc: 0.875646
# **** EPOCH 078 ****
# train_file_idxs is [3 4 1 2 0]
# train file ----0-----
# mean loss: 1.453309
# accuracy: 0.934804
# train file ----1-----
# mean loss: 1.444027
# accuracy: 0.946078
# train file ----2-----
# mean loss: 1.453870
# accuracy: 0.937255
# train file ----3-----
# mean loss: 1.457749
# accuracy: 0.936275
# train file ----4-----
# mean loss: 1.463715
# accuracy: 0.932843
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.461385
# eval accuracy: 0.897059
# eval avg class acc: 0.868330
# **** EPOCH 079 ****
# train_file_idxs is [1 3 0 2 4]
# train file ----0-----
# mean loss: 1.445003
# accuracy: 0.947549
# train file ----1-----
# mean loss: 1.455658
# accuracy: 0.942647
# train file ----2-----
# mean loss: 1.447951
# accuracy: 0.937745
# train file ----3-----
# mean loss: 1.449753
# accuracy: 0.938235
# train file ----4-----
# mean loss: 1.453052
# accuracy: 0.936887
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.452087
# eval accuracy: 0.905229
# eval avg class acc: 0.879456
# **** EPOCH 080 ****
# train_file_idxs is [2 0 3 1 4]
# train file ----0-----
# mean loss: 1.446044
# accuracy: 0.942647
# train file ----1-----
# mean loss: 1.448576
# accuracy: 0.943137
# train file ----2-----
# mean loss: 1.452275
# accuracy: 0.942647
# train file ----3-----
# mean loss: 1.458592
# accuracy: 0.940196
# train file ----4-----
# mean loss: 1.439749
# accuracy: 0.939951
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.460958
# eval accuracy: 0.898693
# eval avg class acc: 0.872936
# Model saved in file: log/model.ckpt
# **** EPOCH 081 ****
# train_file_idxs is [4 1 3 0 2]
# train file ----0-----
# mean loss: 1.437032
# accuracy: 0.944240
# train file ----1-----
# mean loss: 1.438384
# accuracy: 0.945588
# train file ----2-----
# mean loss: 1.442314
# accuracy: 0.944118
# train file ----3-----
# mean loss: 1.459173
# accuracy: 0.936275
# train file ----4-----
# mean loss: 1.441845
# accuracy: 0.951961
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.455828
# eval accuracy: 0.900735
# eval avg class acc: 0.871068
# **** EPOCH 082 ****
# train_file_idxs is [1 4 2 3 0]
# train file ----0-----
# mean loss: 1.438408
# accuracy: 0.949020
# train file ----1-----
# mean loss: 1.444561
# accuracy: 0.939951
# train file ----2-----
# mean loss: 1.443009
# accuracy: 0.942157
# train file ----3-----
# mean loss: 1.440187
# accuracy: 0.944608
# train file ----4-----
# mean loss: 1.441862
# accuracy: 0.944608
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.461217
# eval accuracy: 0.901961
# eval avg class acc: 0.872189
# **** EPOCH 083 ****
# train_file_idxs is [4 3 1 0 2]
# train file ----0-----
# mean loss: 1.436369
# accuracy: 0.943627
# train file ----1-----
# mean loss: 1.441372
# accuracy: 0.945588
# train file ----2-----
# mean loss: 1.432336
# accuracy: 0.948039
# train file ----3-----
# mean loss: 1.441154
# accuracy: 0.940686
# train file ----4-----
# mean loss: 1.444906
# accuracy: 0.948039
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.454305
# eval accuracy: 0.902778
# eval avg class acc: 0.871535
# **** EPOCH 084 ****
# train_file_idxs is [2 0 3 4 1]
# train file ----0-----
# mean loss: 1.436850
# accuracy: 0.947549
# train file ----1-----
# mean loss: 1.449111
# accuracy: 0.941176
# train file ----2-----
# mean loss: 1.440938
# accuracy: 0.943137
# train file ----3-----
# mean loss: 1.434990
# accuracy: 0.952206
# train file ----4-----
# mean loss: 1.442429
# accuracy: 0.942647
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.451033
# eval accuracy: 0.904003
# eval avg class acc: 0.871008
# **** EPOCH 085 ****
# train_file_idxs is [1 3 0 2 4]
# train file ----0-----
# mean loss: 1.429451
# accuracy: 0.951961
# train file ----1-----
# mean loss: 1.436170
# accuracy: 0.945098
# train file ----2-----
# mean loss: 1.435130
# accuracy: 0.946078
# train file ----3-----
# mean loss: 1.450311
# accuracy: 0.939216
# train file ----4-----
# mean loss: 1.437729
# accuracy: 0.946691
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.461713
# eval accuracy: 0.893791
# eval avg class acc: 0.869762
# **** EPOCH 086 ****
# train_file_idxs is [1 2 4 0 3]
# train file ----0-----
# mean loss: 1.430314
# accuracy: 0.949510
# train file ----1-----
# mean loss: 1.431855
# accuracy: 0.946569
# train file ----2-----
# mean loss: 1.433027
# accuracy: 0.946691
# train file ----3-----
# mean loss: 1.438038
# accuracy: 0.945098
# train file ----4-----
# mean loss: 1.431334
# accuracy: 0.946569
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.459293
# eval accuracy: 0.899918
# eval avg class acc: 0.867530
# **** EPOCH 087 ****
# train_file_idxs is [2 3 0 4 1]
# train file ----0-----
# mean loss: 1.440706
# accuracy: 0.942647
# train file ----1-----
# mean loss: 1.434006
# accuracy: 0.943137
# train file ----2-----
# mean loss: 1.436254
# accuracy: 0.945588
# train file ----3-----
# mean loss: 1.427743
# accuracy: 0.952819
# train file ----4-----
# mean loss: 1.434121
# accuracy: 0.948039
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.455938
# eval accuracy: 0.899918
# eval avg class acc: 0.869736
# **** EPOCH 088 ****
# train_file_idxs is [2 3 1 4 0]
# train file ----0-----
# mean loss: 1.436856
# accuracy: 0.943137
# train file ----1-----
# mean loss: 1.441021
# accuracy: 0.938725
# train file ----2-----
# mean loss: 1.441318
# accuracy: 0.947059
# train file ----3-----
# mean loss: 1.431830
# accuracy: 0.945466
# train file ----4-----
# mean loss: 1.429054
# accuracy: 0.950000
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.453403
# eval accuracy: 0.900327
# eval avg class acc: 0.874004
# **** EPOCH 089 ****
# train_file_idxs is [0 1 2 3 4]
# train file ----0-----
# mean loss: 1.433923
# accuracy: 0.946078
# train file ----1-----
# mean loss: 1.429437
# accuracy: 0.949020
# train file ----2-----
# mean loss: 1.437583
# accuracy: 0.945098
# train file ----3-----
# mean loss: 1.436279
# accuracy: 0.944118
# train file ----4-----
# mean loss: 1.437969
# accuracy: 0.946691
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.458598
# eval accuracy: 0.900327
# eval avg class acc: 0.875397
# **** EPOCH 090 ****
# train_file_idxs is [2 1 4 0 3]
# train file ----0-----
# mean loss: 1.426903
# accuracy: 0.950000
# train file ----1-----
# mean loss: 1.431222
# accuracy: 0.947059
# train file ----2-----
# mean loss: 1.439483
# accuracy: 0.943627
# train file ----3-----
# mean loss: 1.440556
# accuracy: 0.938725
# train file ----4-----
# mean loss: 1.445254
# accuracy: 0.943627
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.460121
# eval accuracy: 0.896650
# eval avg class acc: 0.860368
# Model saved in file: log/model.ckpt
# **** EPOCH 091 ****
# train_file_idxs is [0 4 2 3 1]
# train file ----0-----
# mean loss: 1.421223
# accuracy: 0.953431
# train file ----1-----
# mean loss: 1.428523
# accuracy: 0.949142
# train file ----2-----
# mean loss: 1.434017
# accuracy: 0.949510
# train file ----3-----
# mean loss: 1.425447
# accuracy: 0.946569
# train file ----4-----
# mean loss: 1.438477
# accuracy: 0.939706
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.448833
# eval accuracy: 0.904003
# eval avg class acc: 0.869741
# **** EPOCH 092 ****
# train_file_idxs is [4 3 1 2 0]
# train file ----0-----
# mean loss: 1.431247
# accuracy: 0.947304
# train file ----1-----
# mean loss: 1.419804
# accuracy: 0.952451
# train file ----2-----
# mean loss: 1.435471
# accuracy: 0.945098
# train file ----3-----
# mean loss: 1.440639
# accuracy: 0.944608
# train file ----4-----
# mean loss: 1.425931
# accuracy: 0.952941
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.454162
# eval accuracy: 0.900735
# eval avg class acc: 0.863456
# **** EPOCH 093 ****
# train_file_idxs is [2 4 0 1 3]
# train file ----0-----
# mean loss: 1.423375
# accuracy: 0.950000
# train file ----1-----
# mean loss: 1.433035
# accuracy: 0.947304
# train file ----2-----
# mean loss: 1.425862
# accuracy: 0.948039
# train file ----3-----
# mean loss: 1.418343
# accuracy: 0.951471
# train file ----4-----
# mean loss: 1.436657
# accuracy: 0.943627
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.452206
# eval accuracy: 0.901144
# eval avg class acc: 0.868987
# **** EPOCH 094 ****
# train_file_idxs is [3 0 1 2 4]
# train file ----0-----
# mean loss: 1.437999
# accuracy: 0.946078
# train file ----1-----
# mean loss: 1.423040
# accuracy: 0.954412
# train file ----2-----
# mean loss: 1.433259
# accuracy: 0.950000
# train file ----3-----
# mean loss: 1.425300
# accuracy: 0.948529
# train file ----4-----
# mean loss: 1.431619
# accuracy: 0.946691
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.451854
# eval accuracy: 0.900327
# eval avg class acc: 0.874097
# **** EPOCH 095 ****
# train_file_idxs is [4 3 2 1 0]
# train file ----0-----
# mean loss: 1.430224
# accuracy: 0.946078
# train file ----1-----
# mean loss: 1.429134
# accuracy: 0.949020
# train file ----2-----
# mean loss: 1.436943
# accuracy: 0.948039
# train file ----3-----
# mean loss: 1.427145
# accuracy: 0.952941
# train file ----4-----
# mean loss: 1.431313
# accuracy: 0.941176
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.456615
# eval accuracy: 0.899101
# eval avg class acc: 0.863356
# **** EPOCH 096 ****
# train_file_idxs is [0 2 3 1 4]
# train file ----0-----
# mean loss: 1.416394
# accuracy: 0.953922
# train file ----1-----
# mean loss: 1.439166
# accuracy: 0.941667
# train file ----2-----
# mean loss: 1.423978
# accuracy: 0.951471
# train file ----3-----
# mean loss: 1.438006
# accuracy: 0.942647
# train file ----4-----
# mean loss: 1.421585
# accuracy: 0.954657
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.458169
# eval accuracy: 0.899918
# eval avg class acc: 0.870803
# **** EPOCH 097 ****
# train_file_idxs is [3 0 4 1 2]
# train file ----0-----
# mean loss: 1.415940
# accuracy: 0.956373
# train file ----1-----
# mean loss: 1.420108
# accuracy: 0.953431
# train file ----2-----
# mean loss: 1.418616
# accuracy: 0.955882
# train file ----3-----
# mean loss: 1.427972
# accuracy: 0.951471
# train file ----4-----
# mean loss: 1.428000
# accuracy: 0.947549
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.455022
# eval accuracy: 0.899510
# eval avg class acc: 0.870570
# **** EPOCH 098 ****
# train_file_idxs is [1 0 3 2 4]
# train file ----0-----
# mean loss: 1.415429
# accuracy: 0.957843
# train file ----1-----
# mean loss: 1.430943
# accuracy: 0.941667
# train file ----2-----
# mean loss: 1.426436
# accuracy: 0.950980
# train file ----3-----
# mean loss: 1.431781
# accuracy: 0.948039
# train file ----4-----
# mean loss: 1.423972
# accuracy: 0.950368
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.468392
# eval accuracy: 0.892157
# eval avg class acc: 0.859837
# **** EPOCH 099 ****
# train_file_idxs is [4 2 0 3 1]
# train file ----0-----
# mean loss: 1.418176
# accuracy: 0.952206
# train file ----1-----
# mean loss: 1.432953
# accuracy: 0.945098
# train file ----2-----
# mean loss: 1.428176
# accuracy: 0.953922
# train file ----3-----
# mean loss: 1.428700
# accuracy: 0.950000
# train file ----4-----
# mean loss: 1.429341
# accuracy: 0.951961
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.453889
# eval accuracy: 0.901961
# eval avg class acc: 0.867415
# **** EPOCH 100 ****
# train_file_idxs is [4 0 2 1 3]
# train file ----0-----
# mean loss: 1.423215
# accuracy: 0.950368
# train file ----1-----
# mean loss: 1.428369
# accuracy: 0.947549
# train file ----2-----
# mean loss: 1.423877
# accuracy: 0.948039
# train file ----3-----
# mean loss: 1.419170
# accuracy: 0.953922
# train file ----4-----
# mean loss: 1.430913
# accuracy: 0.948039
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.466727
# eval accuracy: 0.899101
# eval avg class acc: 0.878892
# Model saved in file: log/model.ckpt
# **** EPOCH 101 ****
# train_file_idxs is [2 0 1 3 4]
# train file ----0-----
# mean loss: 1.419011
# accuracy: 0.952941
# train file ----1-----
# mean loss: 1.430825
# accuracy: 0.951471
# train file ----2-----
# mean loss: 1.412799
# accuracy: 0.954412
# train file ----3-----
# mean loss: 1.421780
# accuracy: 0.950490
# train file ----4-----
# mean loss: 1.421357
# accuracy: 0.954657
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.466603
# eval accuracy: 0.898693
# eval avg class acc: 0.871851
# **** EPOCH 102 ****
# train_file_idxs is [0 2 3 1 4]
# train file ----0-----
# mean loss: 1.427552
# accuracy: 0.949020
# train file ----1-----
# mean loss: 1.427125
# accuracy: 0.953431
# train file ----2-----
# mean loss: 1.416501
# accuracy: 0.957843
# train file ----3-----
# mean loss: 1.410990
# accuracy: 0.959314
# train file ----4-----
# mean loss: 1.415481
# accuracy: 0.951593
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.458628
# eval accuracy: 0.896242
# eval avg class acc: 0.872692
# **** EPOCH 103 ****
# train_file_idxs is [4 2 0 1 3]
# train file ----0-----
# mean loss: 1.411418
# accuracy: 0.955882
# train file ----1-----
# mean loss: 1.419726
# accuracy: 0.953431
# train file ----2-----
# mean loss: 1.420709
# accuracy: 0.951961
# train file ----3-----
# mean loss: 1.416069
# accuracy: 0.958824
# train file ----4-----
# mean loss: 1.415779
# accuracy: 0.953922
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.454033
# eval accuracy: 0.899510
# eval avg class acc: 0.867382
# **** EPOCH 104 ****
# train_file_idxs is [0 1 3 4 2]
# train file ----0-----
# mean loss: 1.410317
# accuracy: 0.957843
# train file ----1-----
# mean loss: 1.411306
# accuracy: 0.957843
# train file ----2-----
# mean loss: 1.417745
# accuracy: 0.952451
# train file ----3-----
# mean loss: 1.414611
# accuracy: 0.952819
# train file ----4-----
# mean loss: 1.423514
# accuracy: 0.950490
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.450573
# eval accuracy: 0.900735
# eval avg class acc: 0.868197
# **** EPOCH 105 ****
# train_file_idxs is [3 4 1 2 0]
# train file ----0-----
# mean loss: 1.417572
# accuracy: 0.951961
# train file ----1-----
# mean loss: 1.420258
# accuracy: 0.954044
# train file ----2-----
# mean loss: 1.425805
# accuracy: 0.953431
# train file ----3-----
# mean loss: 1.418278
# accuracy: 0.955882
# train file ----4-----
# mean loss: 1.416343
# accuracy: 0.953431
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.448108
# eval accuracy: 0.905637
# eval avg class acc: 0.870900
# **** EPOCH 106 ****
# train_file_idxs is [0 1 3 4 2]
# train file ----0-----
# mean loss: 1.413184
# accuracy: 0.954412
# train file ----1-----
# mean loss: 1.413431
# accuracy: 0.956373
# train file ----2-----
# mean loss: 1.411711
# accuracy: 0.953431
# train file ----3-----
# mean loss: 1.405617
# accuracy: 0.962623
# train file ----4-----
# mean loss: 1.420305
# accuracy: 0.954902
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.455329
# eval accuracy: 0.902778
# eval avg class acc: 0.869367
# **** EPOCH 107 ****
# train_file_idxs is [1 3 2 4 0]
# train file ----0-----
# mean loss: 1.421930
# accuracy: 0.953431
# train file ----1-----
# mean loss: 1.417971
# accuracy: 0.957843
# train file ----2-----
# mean loss: 1.414827
# accuracy: 0.953431
# train file ----3-----
# mean loss: 1.422384
# accuracy: 0.949755
# train file ----4-----
# mean loss: 1.410295
# accuracy: 0.960784
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.455853
# eval accuracy: 0.900327
# eval avg class acc: 0.876330
# **** EPOCH 108 ****
# train_file_idxs is [1 2 0 4 3]
# train file ----0-----
# mean loss: 1.421204
# accuracy: 0.949020
# train file ----1-----
# mean loss: 1.425557
# accuracy: 0.949020
# train file ----2-----
# mean loss: 1.425160
# accuracy: 0.953431
# train file ----3-----
# mean loss: 1.416381
# accuracy: 0.950980
# train file ----4-----
# mean loss: 1.411725
# accuracy: 0.953922
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.455328
# eval accuracy: 0.902778
# eval avg class acc: 0.872628
# **** EPOCH 109 ****
# train_file_idxs is [1 4 2 0 3]
# train file ----0-----
# mean loss: 1.408534
# accuracy: 0.963235
# train file ----1-----
# mean loss: 1.415002
# accuracy: 0.951593
# train file ----2-----
# mean loss: 1.416122
# accuracy: 0.954902
# train file ----3-----
# mean loss: 1.410423
# accuracy: 0.956863
# train file ----4-----
# mean loss: 1.414230
# accuracy: 0.960784
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.453006
# eval accuracy: 0.903186
# eval avg class acc: 0.875781
# **** EPOCH 110 ****
# train_file_idxs is [1 2 3 0 4]
# train file ----0-----
# mean loss: 1.412817
# accuracy: 0.956373
# train file ----1-----
# mean loss: 1.413611
# accuracy: 0.954902
# train file ----2-----
# mean loss: 1.414662
# accuracy: 0.954412
# train file ----3-----
# mean loss: 1.407995
# accuracy: 0.959804
# train file ----4-----
# mean loss: 1.402415
# accuracy: 0.958333
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.456812
# eval accuracy: 0.898693
# eval avg class acc: 0.870355
# Model saved in file: log/model.ckpt
# **** EPOCH 111 ****
# train_file_idxs is [1 0 3 2 4]
# train file ----0-----
# mean loss: 1.400566
# accuracy: 0.963725
# train file ----1-----
# mean loss: 1.402482
# accuracy: 0.958824
# train file ----2-----
# mean loss: 1.407827
# accuracy: 0.963235
# train file ----3-----
# mean loss: 1.420086
# accuracy: 0.954902
# train file ----4-----
# mean loss: 1.412231
# accuracy: 0.957108
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.456784
# eval accuracy: 0.900327
# eval avg class acc: 0.877853
# **** EPOCH 112 ****
# train_file_idxs is [0 4 3 1 2]
# train file ----0-----
# mean loss: 1.417691
# accuracy: 0.952451
# train file ----1-----
# mean loss: 1.404247
# accuracy: 0.958946
# train file ----2-----
# mean loss: 1.418018
# accuracy: 0.955392
# train file ----3-----
# mean loss: 1.419232
# accuracy: 0.948039
# train file ----4-----
# mean loss: 1.415029
# accuracy: 0.955392
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.456011
# eval accuracy: 0.897467
# eval avg class acc: 0.863178
# **** EPOCH 113 ****
# train_file_idxs is [3 0 1 4 2]
# train file ----0-----
# mean loss: 1.410123
# accuracy: 0.957843
# train file ----1-----
# mean loss: 1.418764
# accuracy: 0.954412
# train file ----2-----
# mean loss: 1.399068
# accuracy: 0.961275
# train file ----3-----
# mean loss: 1.419994
# accuracy: 0.953431
# train file ----4-----
# mean loss: 1.415364
# accuracy: 0.955882
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.454498
# eval accuracy: 0.901552
# eval avg class acc: 0.870882
# **** EPOCH 114 ****
# train_file_idxs is [1 0 2 4 3]
# train file ----0-----
# mean loss: 1.410248
# accuracy: 0.959314
# train file ----1-----
# mean loss: 1.411706
# accuracy: 0.954902
# train file ----2-----
# mean loss: 1.409685
# accuracy: 0.954902
# train file ----3-----
# mean loss: 1.415751
# accuracy: 0.952206
# train file ----4-----
# mean loss: 1.409649
# accuracy: 0.959804
# eval file ----0-----
# eval file ----1-----
# eval mean loss: 1.456513
# eval accuracy: 0.898284
# eval avg class acc: 0.869488
# **** EPOCH 115 ****
# train_file_idxs is [1 3 0 4 2]
# train file ----0-----
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-26cea9f82645> in <module>
#       1 if __name__ == "__main__":
# ----> 2     train()
#       3     LOG_FOUT.close()
#
# <ipython-input-7-12ebfc47f9cb> in train()
#     104             # dividing each into pieces of size BATCH_SIZE
#     105             # BATCH_SIZE of clouds with different labels
# --> 106             train_one_epoch(sess, ops, train_writer)
#     107
#     108             # evaluation within every epoch
#
# <ipython-input-7-12ebfc47f9cb> in train_one_epoch(sess, ops, train_writer)
#     163             summary, step, _, loss_value, pred_value = sess.run([ops['merged'], ops['step'],
#     164                                                                  ops['train_op'], ops['loss'], ops['pred']],
# --> 165                                                                 feed_dict=feed_dict)
#     166             train_writer.add_summary(summary, step)
#     167             pred_value = np.argmax(pred_value, 1)  # pred_value is argmax of pred_value probabilities on axis 1
#
# ~/miniconda3/envs/env_gpu_tf1.11/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     885     try:
#     886       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 887                          run_metadata_ptr)
#     888       if run_metadata:
#     889         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/miniconda3/envs/env_gpu_tf1.11/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1108     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1109       results = self._do_run(handle, final_targets, final_fetches,
# -> 1110                              feed_dict_tensor, options, run_metadata)
#    1111     else:
#    1112       results = []
#
# ~/miniconda3/envs/env_gpu_tf1.11/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1284     if handle is None:
#    1285       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1286                            run_metadata)
#    1287     else:
#    1288       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/miniconda3/envs/env_gpu_tf1.11/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1290   def _do_call(self, fn, *args):
#    1291     try:
# -> 1292       return fn(*args)
#    1293     except errors.OpError as e:
#    1294       message = compat.as_text(e.message)
#
# ~/miniconda3/envs/env_gpu_tf1.11/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1275       self._extend_graph()
#    1276       return self._call_tf_sessionrun(
# -> 1277           options, feed_dict, fetch_list, target_list, run_metadata)
#    1278
#    1279     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/miniconda3/envs/env_gpu_tf1.11/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1365     return tf_session.TF_SessionRun_wrapper(
#    1366         self._session, options, feed_dict, fetch_list, target_list,
# -> 1367         run_metadata)
#    1368
#    1369   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
